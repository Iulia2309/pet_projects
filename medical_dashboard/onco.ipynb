# %% [markdown]
# # Лечение злокачественных новообразований в России в 2021 году

# %% [markdown]
# Выполнила: Изъюрова Юлия \
# @yulia_izyurova \
# Ссылка на дашборд: https://datalens.yandex.ru/1ebyefkl68ykq-lechenie-zlokachestvennyh-novoobrazovaniy-v-rossii-v-2

# %% [markdown]
# **Цель работы:**
# создать дашборд в DataLens, который поможет медицинским работникам быстро оценивать состояние онкологической помощи в России.
#
# **Задачи работы:**
# 1. Изучить данные о лечении ЗНО в России в 2021 году.
# 2. Осуществить предобработку данных с помощью Python.
# 3. Создать дашборд в DataLens.
#
# **Исходные данные:**
# Ежегодный отчет главного онколога РФ опубликованного за 2021 год.
# Справочник "Состояние онкологической помощи населению России в 2021 году", таблицы 54, 57-85.
#
# Таблица 54 содержит сведения о лечении ЗНО, впервые зарегистрированных в 2021 г., подлежавших радикальному лечению. В таблице предтавлены суммарные сведения по всей России для всех ЗНО, суммарные сведения для двух возрастных групп детей и суммарные сведения для отдельных локализаций ЗНО (без деления на регионы России). В таблице представлены сведения о количестве ЗНО, радикальное лечения которых закончено или будет продолжено, а также о методах радикального лечения ЗНО.
# Таблица 57 содержит дополительные сведения о лечении больных с ЗНО в 2021 г. по регионам России, без деления на локализации ЗНО. В таблице представлены сведения о количестве отказов от лечения, противопоказаний к лечению, амбулаторном радикальном лечении и видах получаемого лечения.
# Таблицы 58-85 детализируют сведения, представленные в таблице 54, для кажого региона России.
# В таблице 58 представлены сведения для всех ЗНО, в таблицах 59-60 - сведении о лечении детей в двух возрастных категориях, в таблицах 61-85 - сведения о лечении ЗНО различных локализаций.
#
# **План работы:**
# 1. Записать файлы с таблицами в датафреймы.
# 2. Обработать заголовки таблиц.
# 3. Добавить/удалить столбцы при необходимости.
# 4. Разделить/объединить датафреймы при необходимости.
# 5. Записать полученные датафреймы в файлы csv.
# 6. Создать подключение в DataLens с полученными файлами, создать датасеты.
# 7. Создать чарты на основе датасетов.
# 8. Создать дашборд.

# %% [markdown]
# Загрузим необходимые для работы библиотеки

# %%
import pandas as pd
import re
from google.colab import drive
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Запишем url-адреса нужных таблиц в список

# %%
urls = ['https://docs.google.com/spreadsheets/d/1gzlX2gm5Zxaz7mDTx-6KcU9S53szzhJf/edit#gid=1398109345',
        'https://docs.google.com/spreadsheets/d/1veomR9hOaHBaX1GUio4oivMFAf6GwJUb/edit#gid=1504143008',
        'https://docs.google.com/spreadsheets/d/1tYJcgqFOXtTp5l2O-QEJuMayKjZ4I7Up/edit#gid=1561341872',
        'https://docs.google.com/spreadsheets/d/1rPBdrPI5YiVFJ-XYu6DIYpYRe6YixB4H/edit#gid=397533175',
        'https://docs.google.com/spreadsheets/d/1uJcNCJC1-e6mPmOkGaE4oRiLwtv_CKAY/edit#gid=879364898',
        'https://docs.google.com/spreadsheets/d/1ySxpFXGF_s5WWLC5sjUiPz6ksXWUa3K2/edit#gid=1679834351',
        'https://docs.google.com/spreadsheets/d/1Hnx9LZJQKvyjaIllOq6g-47rEAq3b2bT/edit#gid=989420553',
        'https://docs.google.com/spreadsheets/d/14L9v3QbZXm3vt-v4_kauDiA37VsZGsOE/edit#gid=2042173847',
        'https://docs.google.com/spreadsheets/d/1X3_ENrZGbCeb-2yFq3l7ORPCQYGuqeI-/edit#gid=398841154',
        'https://docs.google.com/spreadsheets/d/1vuvgG1Rt9WTjTI4-lumwTiCQWd0EdwMD/edit#gid=130352292',
        'https://docs.google.com/spreadsheets/d/1ts1Rj45VkzHsZvs-_ld-dO0AT3RNoZFF/edit#gid=159999314',
        'https://docs.google.com/spreadsheets/d/1o4P8FYq-7H-ww9JWaK3i2_oIaBcODlFl/edit#gid=483056603',
        'https://docs.google.com/spreadsheets/d/19urfkItHYKgMSyPW1ri-Lqi0LYm_8FiX/edit#gid=436800286',
        'https://docs.google.com/spreadsheets/d/1a1hsjM-MmA6TUwIS3EHuRlhMHZJU3-ML/edit#gid=1513017534',
        'https://docs.google.com/spreadsheets/d/18fhV1blTcfED1ic_Rtxa-cUR5Cc_06OT/edit#gid=2125343112',
        'https://docs.google.com/spreadsheets/d/1DzeDNC0U7MCb_y618ojyozfL6emGKPG4/edit#gid=339736916',
        'https://docs.google.com/spreadsheets/d/1hRP1TlRE23h2uVy08vBQllTL2xcfkZUO/edit#gid=8025642',
        'https://docs.google.com/spreadsheets/d/1sI8Ml7rbVVl4287nj6eIBv3N8lZtPLQd/edit#gid=1598205175',
        'https://docs.google.com/spreadsheets/d/1QdC2oDvVO5iFg_xMHuZbIKv_fjNV0NyK/edit#gid=1219328523',
        'https://docs.google.com/spreadsheets/d/14C5xQVaMzHAg4uoU7TzshORcgY7M_WV_/edit#gid=480890451',
        'https://docs.google.com/spreadsheets/d/1ghd9eMVkMIxEy-bnSTa2volF0QZp7xG6/edit#gid=1681021506',
        'https://docs.google.com/spreadsheets/d/1rLASNIhwgSwD1Et9Romnnr7eSN-_nec1/edit#gid=715172875',
        'https://docs.google.com/spreadsheets/d/1JAOJI1UbtKWa_fMTZl4bAHHaCgGmp_LX/edit#gid=548015351',
        'https://docs.google.com/spreadsheets/d/1GobjArXrt8-t7QAmLp8_PSzmWun8nIVY/edit#gid=1090400024',
        'https://docs.google.com/spreadsheets/d/13SXKRnCUWrwMfi2UXMO719IREaDbVqLj/edit#gid=1375327062',
        'https://docs.google.com/spreadsheets/d/12i1fcyARMJxqN_lgaFVHlMhPiRhI1uor/edit#gid=1236463338',
        'https://docs.google.com/spreadsheets/d/1lOLLS-h9HpA0c6cp34voyJMHR2fFLKnH/edit#gid=117561696',
        'https://docs.google.com/spreadsheets/d/1hTza_2nkMHYOb69P861to3DYaIHZ-LhE/edit#gid=1598494537',
        'https://docs.google.com/spreadsheets/d/1buxEkrueJlbyqWePMgGq7JeHLJ_VxtjR/edit#gid=2007147949',
        'https://docs.google.com/spreadsheets/d/1Vfppv0DwM5exEpR_VM3Cal1aJY6tDcwy/edit#gid=2142140794']

# %% [markdown]
# Преобразуем адреса в URL-адрес экспорта в формате CSV

# %%
new_urls = list(map(lambda url: str.replace(url, '/edit#gid=', '/export?format=csv&gid='), urls))

# %%
new_urls
# Out:
# ['https://docs.google.com/spreadsheets/d/1gzlX2gm5Zxaz7mDTx-6KcU9S53szzhJf/export?format=csv&gid=1398109345',
#  'https://docs.google.com/spreadsheets/d/1veomR9hOaHBaX1GUio4oivMFAf6GwJUb/export?format=csv&gid=1504143008',
#  'https://docs.google.com/spreadsheets/d/1tYJcgqFOXtTp5l2O-QEJuMayKjZ4I7Up/export?format=csv&gid=1561341872',
#  'https://docs.google.com/spreadsheets/d/1rPBdrPI5YiVFJ-XYu6DIYpYRe6YixB4H/export?format=csv&gid=397533175',
#  'https://docs.google.com/spreadsheets/d/1uJcNCJC1-e6mPmOkGaE4oRiLwtv_CKAY/export?format=csv&gid=879364898',
#  'https://docs.google.com/spreadsheets/d/1ySxpFXGF_s5WWLC5sjUiPz6ksXWUa3K2/export?format=csv&gid=1679834351',
#  'https://docs.google.com/spreadsheets/d/1Hnx9LZJQKvyjaIllOq6g-47rEAq3b2bT/export?format=csv&gid=989420553',
#  'https://docs.google.com/spreadsheets/d/14L9v3QbZXm3vt-v4_kauDiA37VsZGsOE/export?format=csv&gid=2042173847',
#  'https://docs.google.com/spreadsheets/d/1X3_ENrZGbCeb-2yFq3l7ORPCQYGuqeI-/export?format=csv&gid=398841154',
#  'https://docs.google.com/spreadsheets/d/1vuvgG1Rt9WTjTI4-lumwTiCQWd0EdwMD/export?format=csv&gid=130352292',
#  'https://docs.google.com/spreadsheets/d/1ts1Rj45VkzHsZvs-_ld-dO0AT3RNoZFF/export?format=csv&gid=159999314',
#  'https://docs.google.com/spreadsheets/d/1o4P8FYq-7H-ww9JWaK3i2_oIaBcODlFl/export?format=csv&gid=483056603',
#  'https://docs.google.com/spreadsheets/d/19urfkItHYKgMSyPW1ri-Lqi0LYm_8FiX/export?format=csv&gid=436800286',
#  'https://docs.google.com/spreadsheets/d/1a1hsjM-MmA6TUwIS3EHuRlhMHZJU3-ML/export?format=csv&gid=1513017534',
#  'https://docs.google.com/spreadsheets/d/18fhV1blTcfED1ic_Rtxa-cUR5Cc_06OT/export?format=csv&gid=2125343112',
#  'https://docs.google.com/spreadsheets/d/1DzeDNC0U7MCb_y618ojyozfL6emGKPG4/export?format=csv&gid=339736916',
#  'https://docs.google.com/spreadsheets/d/1hRP1TlRE23h2uVy08vBQllTL2xcfkZUO/export?format=csv&gid=8025642',
#  'https://docs.google.com/spreadsheets/d/1sI8Ml7rbVVl4287nj6eIBv3N8lZtPLQd/export?format=csv&gid=1598205175',
#  'https://docs.google.com/spreadsheets/d/1QdC2oDvVO5iFg_xMHuZbIKv_fjNV0NyK/export?format=csv&gid=1219328523',
#  'https://docs.google.com/spreadsheets/d/14C5xQVaMzHAg4uoU7TzshORcgY7M_WV_/export?format=csv&gid=480890451',
#  'https://docs.google.com/spreadsheets/d/1ghd9eMVkMIxEy-bnSTa2volF0QZp7xG6/export?format=csv&gid=1681021506',
#  'https://docs.google.com/spreadsheets/d/1rLASNIhwgSwD1Et9Romnnr7eSN-_nec1/export?format=csv&gid=715172875',
#  'https://docs.google.com/spreadsheets/d/1JAOJI1UbtKWa_fMTZl4bAHHaCgGmp_LX/export?format=csv&gid=548015351',
#  'https://docs.google.com/spreadsheets/d/1GobjArXrt8-t7QAmLp8_PSzmWun8nIVY/export?format=csv&gid=1090400024',
#  'https://docs.google.com/spreadsheets/d/13SXKRnCUWrwMfi2UXMO719IREaDbVqLj/export?format=csv&gid=1375327062',
#  'https://docs.google.com/spreadsheets/d/12i1fcyARMJxqN_lgaFVHlMhPiRhI1uor/export?format=csv&gid=1236463338',
#  'https://docs.google.com/spreadsheets/d/1lOLLS-h9HpA0c6cp34voyJMHR2fFLKnH/export?format=csv&gid=117561696',
#  'https://docs.google.com/spreadsheets/d/1hTza_2nkMHYOb69P861to3DYaIHZ-LhE/export?format=csv&gid=1598494537',
#  'https://docs.google.com/spreadsheets/d/1buxEkrueJlbyqWePMgGq7JeHLJ_VxtjR/export?format=csv&gid=2007147949',
#  'https://docs.google.com/spreadsheets/d/1Vfppv0DwM5exEpR_VM3Cal1aJY6tDcwy/export?format=csv&gid=2142140794']

# %% [markdown]
# Загрузим таблицу 54. Передаём преобразованный адрес в pd.read_csv, который может принимать URL-адрес, и записываем результат в датасет table_54. Не будем считывать строки заголовков.

# %%
table_54 = pd.read_csv(new_urls[0], skiprows=4, header=None)

# %% [markdown]
# Посмотрим, как выглядит полученный датасет table_54

# %%
table_54
# Out:
#                                            0                 1       2     3   \
# 0     Злокачественные новообразования - всего            С00-96  271086  50,2
# 1                 У детей в возрасте 0-14 лет            С00-96    1214  40,9
# 2                 У детей в возрасте 0-17 лет            С00-96    1536  42,4
# 3                                        Губа               С00    1472  78,3
# 4                                 Полость рта            C01-09    3376  36,6
# 5                                      Глотка            С10-13    1194  21,9
# 6                                     Пищевод               С15    1693  23,9
# 7                                     Желудок               С16    8652  30,0
# 8                             Ободочная кишка               С18   17945  48,1
# 9    Прямая кишка, ректосиг. соединение, анус            С19-21   12325  43,7
# 10  Печень и внутрипеченочные желчные протоки               С22     626  10,6
# 11                       Поджелудочная железа               С25    1856  12,3
# 12                                    Гортань               С32    2630  44,2
# 13                     Трахея, бронхи, легкое            С33,34   12848  26,5
# 14                    Кости и суставные хрящи            С40,41     450  36,8
# 15                              Меланома кожи               С43    8327  73,8
# 16                      Кожа (кроме меланомы)               С44   58324  85,5
# 17       Соединительная и другие мягкие ткани            С47,49    1661  52,7
# 18                            Молочная железа               С50   37873  54,8
# 19                                Шейка матки               С53    8646  57,6
# 20                                 Тело матки               С54   17477  70,7
# 21                                     Яичник               С56    6126  48,8
# 22                      Предстательная железа               С61   13076  33,7
# 23                                      Почка               С64   14014  67,7
# 24                             Мочевой пузырь               С67   10089  67,9
# 25                          Щитовидная железа               С73   10143  82,1
# 26                    Злокачественные лимфомы  С81-86;88, 90,96    5748  38,0
# 27                                   Лейкемии            С91-95    3322  35,7
#
#        4     5     6     7     8     9     10
# 0   94295  17,5  58,7   6,9   3,0  29,3   2,1
# 1    1205  40,6  29,0   1,1  39,6  27,9   2,4
# 2    1428  39,4  31,4   1,2  36,7  28,1   2,7
# 3     178   9,5  58,6  27,5   0,0  12,4   1,5
# 4    1635  17,7  38,2  12,3   0,0  36,9  12,6
# 5     907  16,6  17,3  17,3   0,0  37,2  28,1
# 6    1403  19,8  41,9   1,5   0,0  43,7  12,9
# 7    4572  15,9  57,8   0,0   0,0  42,0   0,2
# 8    5950  15,9  64,9   0,0   0,0  35,1   0,0
# 9    6312  22,4  44,7   4,1   0,0  45,1   6,1
# 10    711  12,0  59,7   0,0   0,0  39,9   0,3
# 11   1840  12,2  52,5   0,0   0,0  47,5   0,0
# 12   1154  19,4  33,9  17,0   0,0  39,8   9,3
# 13   7509  15,5  57,3   1,2   0,0  38,4   3,0
# 14    275  22,5  62,7   0,0   0,0  37,1   0,2
# 15   1324  11,7  87,8   0,0   0,0  12,0   0,2
# 16   4491   6,6  74,9  21,8   0,0   3,1   0,2
# 17    567  18,0  69,1   0,3   0,0  30,4   0,2
# 18  18972  27,5  36,2   0,0   0,0  63,8   0,0
# 19   2965  19,8  40,3  14,8   0,0  27,4  17,4
# 20   3362  13,6  63,0   0,9   0,0  35,9   0,2
# 21   2775  22,1  45,2   0,0   0,0  54,8   0,0
# 22  10107  26,0  49,5  12,5   0,0  33,9   4,1
# 23   1329   6,4  94,3   0,0   0,0   5,3   0,4
# 24   1993  13,4  67,9   0,2   0,0  30,5   1,4
# 25   1032   8,4  81,9   0,6   0,0  17,5   0,0
# 26   4759  31,5   1,5   0,1  78,7  10,7   9,0
# 27   3562  38,3   0,0   0,0  96,1   3,5   0,4

# %% [markdown]
# Выведем общую информацию о датасете `table_54`

# %%
table_54.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       28 non-null     object
#  1   1       28 non-null     object
#  2   2       28 non-null     int64
#  3   3       28 non-null     object
#  4   4       28 non-null     int64
#  5   5       28 non-null     object
#  6   6       28 non-null     object
#  7   7       28 non-null     object
#  8   8       28 non-null     object
#  9   9       28 non-null     object
#  10  10      28 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 2.5+ KB

# %% [markdown]
# Поменяем тип данных object на float, там где это нужно

# %%
for k in [3, 5, 6, 7, 8, 9, 10]:
    table_54.loc[:, k] = table_54.loc[:, k].str.replace(',', '.').astype('float')

# %% [markdown]
# Дадим названия столбцам датасета `table_54`

# %%
table_54.columns = ['Локализация опухоли',
                    'Код МКБ-10',
                    'Радикальное лечение закончено в отчетном году, абс.',
                    'Радикальное лечение закончено в отчетном году, %',
                    'Лечение будет продолжено, абс.',
                    'Лечение будет продолжено, %',
                    'Хирургический метод, %',
                    'Лучевой метод, %',
                    'Лекарственный метод, %',
                    'Комбинированный метод (кроме химио-лучевого), %',
                    'Химио-лучевой метод, %']

# %% [markdown]
# В столбцах `Код МКБ-10` таблиц 54, 58-85, по-видимому, встречаются 'C' в кириллице и латинице. Объявим функцию, которая будет заменять их на латиницу

# %%
def c_mkb(table):
    table['Код МКБ-10'] = table['Код МКБ-10'].str.replace('С', 'C')
    return table

# %% [markdown]
# Применим функцию c_mkb к датасету `table_54`

# %%
table_54 = c_mkb(table_54)

# %%
table_54.head()
# Out:
#                        Локализация опухоли Код МКБ-10  \
# 0  Злокачественные новообразования - всего     C00-96
# 1              У детей в возрасте 0-14 лет     C00-96
# 2              У детей в возрасте 0-17 лет     C00-96
# 3                                     Губа        C00
# 4                              Полость рта     C01-09
#
#    Радикальное лечение закончено в отчетном году, абс.  \
# 0                                             271086
# 1                                               1214
# 2                                               1536
# 3                                               1472
# 4                                               3376
#
#    Радикальное лечение закончено в отчетном году, %  \
# 0                                              50.2
# 1                                              40.9
# 2                                              42.4
# 3                                              78.3
# 4                                              36.6
#
#    Лечение будет продолжено, абс.  Лечение будет продолжено, %  \
# 0                           94295                         17.5
# 1                            1205                         40.6
# 2                            1428                         39.4
# 3                             178                          9.5
# 4                            1635                         17.7
#
#    Хирургический метод, %  Лучевой метод, %  Лекарственный метод, %  \
# 0                    58.7               6.9                     3.0
# 1                    29.0               1.1                    39.6
# 2                    31.4               1.2                    36.7
# 3                    58.6              27.5                     0.0
# 4                    38.2              12.3                     0.0
#
#    Комбинированный метод (кроме химио-лучевого), %  Химио-лучевой метод, %
# 0                                             29.3                     2.1
# 1                                             27.9                     2.4
# 2                                             28.1                     2.7
# 3                                             12.4                     1.5
# 4                                             36.9                    12.6

# %% [markdown]
# Создадим отдельный небольшой датасет с методами радикального лечения по всей России на основе данных из таблицы 54. Это понадобится для построения круговой диаграммы в DataLens с целью оценки распределения методов лечения в среднем по  стране.

# %%
methods = {'Лечение': ['Хирургическое', 'Лучевое', 'Лекарственное', 'Комбинированное',  'Химио-Лучевое'], 'Доля': [58.7, 6.9, 3.0, 29.3, 2.1]}
rus_methods = pd.DataFrame.from_dict(methods)
rus_methods
# Out:
#            Лечение  Доля
# 0    Хирургическое  58.7
# 1          Лучевое   6.9
# 2    Лекарственное   3.0
# 3  Комбинированное  29.3
# 4    Химио-Лучевое   2.1

# %% [markdown]
# Загрузим таблицу 57. Передаём преобразованный адрес в pd.read_csv, который может принимать URL-адрес, и записываем результат в датасет table_57. Не будем считывать строки заголовков.

# %%
table_57 = pd.read_csv(new_urls[1], skiprows=7, header=None)

# %% [markdown]
# Посмотрим, как выглядит полученный датасет table_57

# %%
table_57
# Out:
#                           0     1    2     3     4     5     6     7     8   \
# 0             ЦЕНТРАЛЬНЫЙ ФО  1810  1,3  1017  56,2  8352   5,9  4337  51,9
# 1       Белгородская область    90  1,3    30  33,3   132   1,9    22  16,7
# 2           Брянская область    20  0,4     9  45,0    97   1,7    12  12,4
# 3       Владимирская область   107  1,9    71  66,4   245   4,5   100  40,8
# 4        Воронежская область   111  1,2    41  36,9   335   3,7    82  24,5
# ..                       ...   ...  ...   ...   ...   ...   ...   ...   ...
# 88        Забайкальский край   190  5,6   101  53,2   325   9,6   164  50,5
# 89       Чукотский авт.округ     3  2,7     2  66,7     2   1,8     0   0,0
# 90        Республика Бурятия    88  2,6    39  44,3   234   6,9    40  17,1
# 91  Республика Саха (Якутия)    22  1,0     9  40,9   187   8,1    37  19,8
# 92       Еврейская авт. обл.    16  2,8    10  62,5    58  10,3    34  58,6
#
#       9   ...     13      14      15    16     17     18    19     20     21  \
# 0   9175  ...  34412  133000  123736  93,0  36690  34412  93,8  51253  45348
# 1    713  ...   1991    4631    4560  98,5   2044   1991  97,4   2437   2394
# 2    515  ...   1420    5716    5700  99,7   1438   1420  98,7   1587   1570
# 3    304  ...   1257    7443    6949  93,4   1347   1257  93,3   3187   2270
# 4    648  ...   2637    9896    9839  99,4   2653   2637  99,4   3912   3878
# ..   ...  ...    ...     ...     ...   ...    ...    ...   ...    ...    ...
# 88   144  ...    805    4263    3757  88,1    917    805  87,8   1982   1519
# 89     0  ...      6      63      53  84,1      7      6  85,7     13     11
# 90   275  ...    981    6269    6145  98,0    986    981  99,5   7458   7386
# 91     0  ...    412    1797    1624  90,4    414    412  99,5    573    530
# 92    53  ...     82     485     385  79,4    108     82  75,9    484    193
#
#       22
# 0   88,5
# 1   98,2
# 2   98,9
# 3   71,2
# 4   99,1
# ..   ...
# 88  76,6
# 89  84,6
# 90  99,0
# 91  92,5
# 92  39,9
#
# [93 rows x 23 columns]

# %% [markdown]
# Выведем общую информацию о датасете `table_57`

# %%
table_57.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       93 non-null     object
#  1   1       93 non-null     int64
#  2   2       93 non-null     object
#  3   3       93 non-null     int64
#  4   4       93 non-null     object
#  5   5       93 non-null     int64
#  6   6       93 non-null     object
#  7   7       93 non-null     int64
#  8   8       93 non-null     object
#  9   9       93 non-null     int64
#  10  10      93 non-null     object
#  11  11      93 non-null     int64
#  12  12      93 non-null     int64
#  13  13      93 non-null     int64
#  14  14      93 non-null     int64
#  15  15      93 non-null     int64
#  16  16      93 non-null     object
#  17  17      93 non-null     int64
#  18  18      93 non-null     int64
#  19  19      93 non-null     object
#  20  20      93 non-null     int64
#  21  21      93 non-null     int64
#  22  22      93 non-null     object
# dtypes: int64(14), object(9)
# memory usage: 16.8+ KB

# %% [markdown]
# Поменяем тип данных object на float, там где это нужно

# %%
for k in [2, 4, 6, 8, 10, 16, 19, 22]:
    table_57.loc[:, k] = table_57.loc[:, k].str.replace(',', '.').astype('float')

# %% [markdown]
# Дадим названия всем столбцам датасета table_57

# %%
table_57.columns = ['Регион',
                    'Отказы от лечения, абс.',
                    'Отказы от лечения, %',
                    'Отказы от лечения I-II ст., абс.',
                    'Отказы от лечения I-II ст., %',
                    'Противопоказания  к лечению, абс.',
                    'Противопоказания  к лечению, %',
                    'Противопоказания  к лечению I-II ст., абс.',
                    'Противопоказания  к лечению I-II ст., %',
                    'Амбулаторное радикальное лечение, абс.',
                    'Амбулаторное радикальное лечение, %',
                    'Число больных, закончивших лекарственное лечение, абс.',
                    'Число больных гемобластозами, закончивших лекарственное лечение, абс.',
                    'Число больных, закончивших лучевое лечение, абс.',
                    'Число больных, подлежащих лекарственному лечению, абс.',
                    'Число больных, получавших лекарственное лечение, абс.',
                    'Число больных, получавших лекарственное лечение, %',
                    'Число больных, подлежащих лучевому лечению, абс.',
                    'Число больных, получавших лучевое лечение, абс.',
                    'Число больных, получавших лучевое лечение, %',
                    'Число больных, подлежащих комбинированному лечению, абс.',
                    'Число больных, получавших комбинированное лечение, абс.',
                    'Число больных, получавших комбинированное лечение, %']

# %%
table_57.head()
# Out:
#                  Регион  Отказы от лечения, абс.  Отказы от лечения, %  \
# 0        ЦЕНТРАЛЬНЫЙ ФО                     1810                   1.3
# 1  Белгородская область                       90                   1.3
# 2      Брянская область                       20                   0.4
# 3  Владимирская область                      107                   1.9
# 4   Воронежская область                      111                   1.2
#
#    Отказы от лечения I-II ст., абс.  Отказы от лечения I-II ст., %  \
# 0                              1017                           56.2
# 1                                30                           33.3
# 2                                 9                           45.0
# 3                                71                           66.4
# 4                                41                           36.9
#
#    Противопоказания  к лечению, абс.  Противопоказания  к лечению, %  \
# 0                               8352                             5.9
# 1                                132                             1.9
# 2                                 97                             1.7
# 3                                245                             4.5
# 4                                335                             3.7
#
#    Противопоказания  к лечению I-II ст., абс.  \
# 0                                        4337
# 1                                          22
# 2                                          12
# 3                                         100
# 4                                          82
#
#    Противопоказания  к лечению I-II ст., %  \
# 0                                     51.9
# 1                                     16.7
# 2                                     12.4
# 3                                     40.8
# 4                                     24.5
#
#    Амбулаторное радикальное лечение, абс.  ...  \
# 0                                    9175  ...
# 1                                     713  ...
# 2                                     515  ...
# 3                                     304  ...
# 4                                     648  ...
#
#    Число больных, закончивших лучевое лечение, абс.  \
# 0                                             34412
# 1                                              1991
# 2                                              1420
# 3                                              1257
# 4                                              2637
#
#    Число больных, подлежащих лекарственному лечению, абс.  \
# 0                                             133000
# 1                                               4631
# 2                                               5716
# 3                                               7443
# 4                                               9896
#
#    Число больных, получавших лекарственное лечение, абс.  \
# 0                                             123736
# 1                                               4560
# 2                                               5700
# 3                                               6949
# 4                                               9839
#
#    Число больных, получавших лекарственное лечение, %  \
# 0                                               93.0
# 1                                               98.5
# 2                                               99.7
# 3                                               93.4
# 4                                               99.4
#
#    Число больных, подлежащих лучевому лечению, абс.  \
# 0                                             36690
# 1                                              2044
# 2                                              1438
# 3                                              1347
# 4                                              2653
#
#    Число больных, получавших лучевое лечение, абс.  \
# 0                                            34412
# 1                                             1991
# 2                                             1420
# 3                                             1257
# 4                                             2637
#
#    Число больных, получавших лучевое лечение, %  \
# 0                                          93.8
# 1                                          97.4
# 2                                          98.7
# 3                                          93.3
# 4                                          99.4
#
#    Число больных, подлежащих комбинированному лечению, абс.  \
# 0                                              51253
# 1                                               2437
# 2                                               1587
# 3                                               3187
# 4                                               3912
#
#    Число больных, получавших комбинированное лечение, абс.  \
# 0                                              45348
# 1                                               2394
# 2                                               1570
# 3                                               2270
# 4                                               3878
#
#    Число больных, получавших комбинированное лечение, %
# 0                                               88.5
# 1                                               98.2
# 2                                               98.9
# 3                                               71.2
# 4                                               99.1
#
# [5 rows x 23 columns]

# %% [markdown]
# Объявим функцию, которая будет добавлять в датасет столбец 'Федеральный округ' и заполнять его соответствующими названиями.

# %%
def fo_column_creation(table):
    #Вставляем новый столбец
    table.insert(0,'Федеральный округ', '')
    #Проходим по столбцу 'Республика, край, область'
    for i in range(len(table['Регион'])):
        #Ищем названия, написанные заглавными буквами - это страна и федеральные округа
        if table['Регион'][i].isupper():
            #Разбиваем название федеральных округов на два слова (название и ФО)
            fo = table['Регион'][i].split()
            #Название федерального округа записываем с заглавной буквы
            fo[0] = fo[0].capitalize()
            #Учтём случаи двойных названий ФО
            if re.search(r'-', fo[0]):
                fo2 = fo[0].split('-')
                fo2[1] = fo2[1].capitalize()
                fo[0] = '-'.join(fo2)
            #Заносим название федрального округа в соответствующий столбец, начиная со строки, где название встречается в столбце 'Республика, край, область'
            table.loc[i:, 'Федеральный округ'] = ' '.join(fo)
            #Удаляем лишние строки, содержащие данные по федеральным округам
            table = table.drop(index=i, axis=0)
    return table

# %% [markdown]
# Применим функцию `fo_column_creation` к датасету `table_57`

# %%
table_57 = fo_column_creation(table_57)

# %%
table_57.head(20)
# Out:
#      Федеральный округ                     Регион  Отказы от лечения, абс.  \
# 1       Центральный ФО       Белгородская область                       90
# 2       Центральный ФО           Брянская область                       20
# 3       Центральный ФО       Владимирская область                      107
# 4       Центральный ФО        Воронежская область                      111
# 5       Центральный ФО         Ивановская область                       43
# 6       Центральный ФО           Тверская область                       79
# 7       Центральный ФО          Калужская область                       11
# 8       Центральный ФО        Костромская область                       20
# 9       Центральный ФО            Курская область                       35
# 10      Центральный ФО           Липецкая область                       30
# 11      Центральный ФО                  г. Москва                      672
# 12      Центральный ФО         Московская область                      263
# 13      Центральный ФО          Орловская область                       53
# 14      Центральный ФО          Рязанская область                        7
# 15      Центральный ФО         Смоленская область                       44
# 16      Центральный ФО         Тамбовская область                       65
# 17      Центральный ФО           Тульская область                       41
# 18      Центральный ФО        Ярославская область                      119
# 20  Северо-Западный ФО              Ненецкий а.о.                        0
# 21  Северо-Западный ФО  Архангельская обл.(б/а.о)                       33
#
#     Отказы от лечения, %  Отказы от лечения I-II ст., абс.  \
# 1                    1.3                                30
# 2                    0.4                                 9
# 3                    1.9                                71
# 4                    1.2                                41
# 5                    0.9                                26
# 6                    1.5                                38
# 7                    0.3                                 7
# 8                    0.8                                 4
# 9                    0.7                                 6
# 10                   0.6                                21
# 11                   1.9                               475
# 12                   1.1                                78
# 13                   1.7                                39
# 14                   0.1                                 5
# 15                   1.1                                16
# 16                   1.6                                25
# 17                   0.7                                33
# 18                   1.9                                93
# 20                   0.0                                 0
# 21                   0.7                                25
#
#     Отказы от лечения I-II ст., %  Противопоказания  к лечению, абс.  \
# 1                            33.3                                132
# 2                            45.0                                 97
# 3                            66.4                                245
# 4                            36.9                                335
# 5                            60.5                                118
# 6                            48.1                                331
# 7                            63.6                                 45
# 8                            20.0                                 25
# 9                            17.1                                 29
# 10                           70.0                                132
# 11                           70.7                               4353
# 12                           29.7                                659
# 13                           73.6                                300
# 14                           71.4                                350
# 15                           36.4                                 42
# 16                           38.5                                123
# 17                           80.5                                492
# 18                           78.2                                544
# 20                            0.0                                  6
# 21                           75.8                                375
#
#     Противопоказания  к лечению, %  \
# 1                              1.9
# 2                              1.7
# 3                              4.5
# 4                              3.7
# 5                              2.6
# 6                              6.1
# 7                              1.0
# 8                              1.0
# 9                              0.6
# 10                             2.8
# 11                            12.4
# 12                             2.7
# 13                             9.6
# 14                             7.2
# 15                             1.0
# 16                             3.0
# 17                             8.5
# 18                             8.8
# 20                             5.9
# 21                             7.6
#
#     Противопоказания  к лечению I-II ст., абс.  \
# 1                                           22
# 2                                           12
# 3                                          100
# 4                                           82
# 5                                           25
# 6                                          139
# 7                                           18
# 8                                            3
# 9                                            6
# 10                                          60
# 11                                        2853
# 12                                         151
# 13                                         106
# 14                                         171
# 15                                          23
# 16                                          41
# 17                                         258
# 18                                         267
# 20                                           3
# 21                                         153
#
#     Противопоказания  к лечению I-II ст., %  ...  \
# 1                                      16.7  ...
# 2                                      12.4  ...
# 3                                      40.8  ...
# 4                                      24.5  ...
# 5                                      21.2  ...
# 6                                      42.0  ...
# 7                                      40.0  ...
# 8                                      12.0  ...
# 9                                      20.7  ...
# 10                                     45.5  ...
# 11                                     65.5  ...
# 12                                     22.9  ...
# 13                                     35.3  ...
# 14                                     48.9  ...
# 15                                     54.8  ...
# 16                                     33.3  ...
# 17                                     52.4  ...
# 18                                     49.1  ...
# 20                                     50.0  ...
# 21                                     40.8  ...
#
#     Число больных, закончивших лучевое лечение, абс.  \
# 1                                               1991
# 2                                               1420
# 3                                               1257
# 4                                               2637
# 5                                               1462
# 6                                               1042
# 7                                                849
# 8                                                512
# 9                                               2026
# 10                                              2138
# 11                                              8211
# 12                                              4907
# 13                                               685
# 14                                              1168
# 15                                               701
# 16                                               752
# 17                                              1567
# 18                                              1087
# 20                                                29
# 21                                              1456
#
#     Число больных, подлежащих лекарственному лечению, абс.  \
# 1                                                4631
# 2                                                5716
# 3                                                7443
# 4                                                9896
# 5                                                5103
# 6                                                4243
# 7                                                3088
# 8                                                1584
# 9                                                3749
# 10                                               5636
# 11                                              35940
# 12                                              26946
# 13                                               2733
# 14                                               3396
# 15                                               2731
# 16                                               1129
# 17                                               4915
# 18                                               4121
# 20                                                106
# 21                                               4574
#
#     Число больных, получавших лекарственное лечение, абс.  \
# 1                                                4560
# 2                                                5700
# 3                                                6949
# 4                                                9839
# 5                                                5051
# 6                                                4174
# 7                                                2060
# 8                                                1550
# 9                                                3710
# 10                                               5473
# 11                                              33589
# 12                                              24151
# 13                                               2463
# 14                                               3384
# 15                                               2722
# 16                                               1071
# 17                                               3221
# 18                                               4069
# 20                                                100
# 21                                               4538
#
#     Число больных, получавших лекарственное лечение, %  \
# 1                                                98.5
# 2                                                99.7
# 3                                                93.4
# 4                                                99.4
# 5                                                99.0
# 6                                                98.4
# 7                                                66.7
# 8                                                97.9
# 9                                                99.0
# 10                                               97.1
# 11                                               93.5
# 12                                               89.6
# 13                                               90.1
# 14                                               99.6
# 15                                               99.7
# 16                                               94.9
# 17                                               65.5
# 18                                               98.7
# 20                                               94.3
# 21                                               99.2
#
#     Число больных, подлежащих лучевому лечению, абс.  \
# 1                                               2044
# 2                                               1438
# 3                                               1347
# 4                                               2653
# 5                                               1478
# 6                                               1069
# 7                                                849
# 8                                                528
# 9                                               2051
# 10                                              2317
# 11                                              8785
# 12                                              5592
# 13                                               715
# 14                                              1175
# 15                                               739
# 16                                               862
# 17                                              1946
# 18                                              1102
# 20                                                29
# 21                                              1473
#
#     Число больных, получавших лучевое лечение, абс.  \
# 1                                              1991
# 2                                              1420
# 3                                              1257
# 4                                              2637
# 5                                              1462
# 6                                              1042
# 7                                               849
# 8                                               512
# 9                                              2026
# 10                                             2138
# 11                                             8211
# 12                                             4907
# 13                                              685
# 14                                             1168
# 15                                              701
# 16                                              752
# 17                                             1567
# 18                                             1087
# 20                                               29
# 21                                             1456
#
#     Число больных, получавших лучевое лечение, %  \
# 1                                           97.4
# 2                                           98.7
# 3                                           93.3
# 4                                           99.4
# 5                                           98.9
# 6                                           97.5
# 7                                          100.0
# 8                                           97.0
# 9                                           98.8
# 10                                          92.3
# 11                                          93.5
# 12                                          87.8
# 13                                          95.8
# 14                                          99.4
# 15                                          94.9
# 16                                          87.2
# 17                                          80.5
# 18                                          98.6
# 20                                         100.0
# 21                                          98.8
#
#     Число больных, подлежащих комбинированному лечению, абс.  \
# 1                                                2437
# 2                                                1587
# 3                                                3187
# 4                                                3912
# 5                                                3373
# 6                                                1552
# 7                                                 570
# 8                                                 483
# 9                                                5794
# 10                                               2872
# 11                                               4898
# 12                                               9845
# 13                                               1316
# 14                                               1495
# 15                                                920
# 16                                               1238
# 17                                               3899
# 18                                               1875
# 20                                                 39
# 21                                               1811
#
#     Число больных, получавших комбинированное лечение, абс.  \
# 1                                                2394
# 2                                                1570
# 3                                                2270
# 4                                                3878
# 5                                                3341
# 6                                                1481
# 7                                                 570
# 8                                                 472
# 9                                                5730
# 10                                               2731
# 11                                               4578
# 12                                               8384
# 13                                               1263
# 14                                               1481
# 15                                                916
# 16                                                901
# 17                                               1658
# 18                                               1730
# 20                                                 39
# 21                                               1807
#
#     Число больных, получавших комбинированное лечение, %
# 1                                                98.2
# 2                                                98.9
# 3                                                71.2
# 4                                                99.1
# 5                                                99.1
# 6                                                95.4
# 7                                               100.0
# 8                                                97.7
# 9                                                98.9
# 10                                               95.1
# 11                                               93.5
# 12                                               85.2
# 13                                               96.0
# 14                                               99.1
# 15                                               99.6
# 16                                               72.8
# 17                                               42.5
# 18                                               92.3
# 20                                              100.0
# 21                                               99.8
#
# [20 rows x 24 columns]

# %% [markdown]
# Добавим в датасет `table_57` три столбца с градациями по долям получивших разные виды лечения (это понадобится для построения линейчатой диаграммы в DataLens с целью оценки разных регионов)

# %%
 table_57['Градация получавших лек. леч.'] = table_57['Число больных, получавших лекарственное лечение, %'] \
                                                  .apply(lambda x: '97-100 %' if x >= 97
                                                                              else ('93-96 %' if x >= 93
                                                                                    else ('88-92 %' if x >= 88
                                                                                          else ('80-89 %' if x >= 80
                                                                                                else ('<80 %'
                                                                                                )
                                                                                          )
                                                                                    )
                                                                              )
                                                  )

# %%
table_57['Градация получавших луч. леч.'] = table_57['Число больных, получавших лучевое лечение, %'] \
                                                  .apply(lambda x: '97-100 %' if x >= 97
                                                                              else ('93-96 %' if x >= 93
                                                                                    else ('88-92 %' if x >= 88
                                                                                          else ('80-89 %' if x >= 80
                                                                                                else ('<80 %'
                                                                                                )
                                                                                          )
                                                                                    )
                                                                              )
                                                  )

# %%
table_57['Градация получавших комб. леч.'] = table_57['Число больных, получавших комбинированное лечение, %'] \
                                                  .apply(lambda x: '97-100 %' if x >= 97
                                                                              else ('93-96 %' if x >= 93
                                                                                    else ('88-92 %' if x >= 88
                                                                                          else ('80-89 %' if x >= 80
                                                                                                else ('<80 %'
                                                                                                )
                                                                                          )
                                                                                    )
                                                                              )
                                                  )

# %%
table_57.head()
# Out:
#   Федеральный округ                Регион  Отказы от лечения, абс.  \
# 1    Центральный ФО  Белгородская область                       90
# 2    Центральный ФО      Брянская область                       20
# 3    Центральный ФО  Владимирская область                      107
# 4    Центральный ФО   Воронежская область                      111
# 5    Центральный ФО    Ивановская область                       43
#
#    Отказы от лечения, %  Отказы от лечения I-II ст., абс.  \
# 1                   1.3                                30
# 2                   0.4                                 9
# 3                   1.9                                71
# 4                   1.2                                41
# 5                   0.9                                26
#
#    Отказы от лечения I-II ст., %  Противопоказания  к лечению, абс.  \
# 1                           33.3                                132
# 2                           45.0                                 97
# 3                           66.4                                245
# 4                           36.9                                335
# 5                           60.5                                118
#
#    Противопоказания  к лечению, %  Противопоказания  к лечению I-II ст., абс.  \
# 1                             1.9                                          22
# 2                             1.7                                          12
# 3                             4.5                                         100
# 4                             3.7                                          82
# 5                             2.6                                          25
#
#    Противопоказания  к лечению I-II ст., %  ...  \
# 1                                     16.7  ...
# 2                                     12.4  ...
# 3                                     40.8  ...
# 4                                     24.5  ...
# 5                                     21.2  ...
#
#    Число больных, получавших лекарственное лечение, %  \
# 1                                               98.5
# 2                                               99.7
# 3                                               93.4
# 4                                               99.4
# 5                                               99.0
#
#    Число больных, подлежащих лучевому лечению, абс.  \
# 1                                              2044
# 2                                              1438
# 3                                              1347
# 4                                              2653
# 5                                              1478
#
#    Число больных, получавших лучевое лечение, абс.  \
# 1                                             1991
# 2                                             1420
# 3                                             1257
# 4                                             2637
# 5                                             1462
#
#    Число больных, получавших лучевое лечение, %  \
# 1                                          97.4
# 2                                          98.7
# 3                                          93.3
# 4                                          99.4
# 5                                          98.9
#
#    Число больных, подлежащих комбинированному лечению, абс.  \
# 1                                               2437
# 2                                               1587
# 3                                               3187
# 4                                               3912
# 5                                               3373
#
#    Число больных, получавших комбинированное лечение, абс.  \
# 1                                               2394
# 2                                               1570
# 3                                               2270
# 4                                               3878
# 5                                               3341
#
#    Число больных, получавших комбинированное лечение, %  \
# 1                                               98.2
# 2                                               98.9
# 3                                               71.2
# 4                                               99.1
# 5                                               99.1
#
#    Градация получавших лек. леч.  Градация получавших луч. леч.  \
# 1                       97-100 %                       97-100 %
# 2                       97-100 %                       97-100 %
# 3                        93-96 %                        93-96 %
# 4                       97-100 %                       97-100 %
# 5                       97-100 %                       97-100 %
#
#    Градация получавших комб. леч.
# 1                        97-100 %
# 2                        97-100 %
# 3                           <80 %
# 4                        97-100 %
# 5                        97-100 %
#
# [5 rows x 27 columns]

# %% [markdown]
# Получим названия локализаций опухолей и возрастных групп, а также кодов МКБ-10  из таблиц с 58 по 80 с помощью регулярных выражений

# %%
localization = []
pattern=r'[А-Я](?:\s[а-я]|[а-я]).+\(.+\)'
for j in range(2, len(new_urls)):
    localization.append(re.search(pattern, pd.read_csv(new_urls[j], nrows=1, header=None)[0][0]).group(0))

# %%
for n in localization:
    print(n)
# Out:
# Злокачественные новообразования - всего (С00-96)
# У детей в возрасте 0-14 лет (С00-96)
# У детей в возрасте 0-17 лет (С00-96)
# Губа (С00)
# Полость рта (C01-09)
# Глотка (С10-13)
# Пищевод (С15)
# Желудок (С16)
# Ободочная кишка (С18)
# Прямая кишка, ректосиг. соединение, анус (С19-21)
# Печень и внутрипеченочные желчные протоки (С22)
# Поджелудочная железа (С25)
# Гортань (С32)
# Трахея, бронхи, легкое (С33,34)
# Кости и суставные хрящи (С40,41)
# Меланома кожи (С43)
# Кожа (кроме меланомы) (С44)
# Соединительная и другие мягкие ткани (С47,49)
# Молочная железа (С50)
# Шейка матки (С53)
# Тело матки (С54)
# Яичник (С56)
# Предстательная железа (С61)
# Почка (С64)
# Мочевой пузырь (С67)
# Щитовидная железа (С73)
# Злокачественные лимфомы (С81-86;88,90,96)
# Лейкемии (С91-95)

# %% [markdown]
# Таблицы с 58 по 80 однотипны. Воспользуемся циклом для генерации имён датасетов и запишем в них таблицы.

# %%
#Создадим пустой список, в который будем заносить сгенерированные имена таблиц
tables = []
#Зададим счётчик url-адреса таблицы в списке `new_urls`
j = 2
#Пройдём циклом по номерам таблиц
for i in range(58, 86):
    #Загрузим таблицы без заголовков
    vars()['table_'+ str(i)]= pd.read_csv(new_urls[j], skiprows=4, header=None)
    #Поменяем тип данных object на float, там где это нужно
    for k in [2, 4, 5, 6, 7, 8, 9]:
        vars()['table_'+ str(i)].loc[:, k] = vars()['table_'+ str(i)].loc[:, k].str.replace(',', '.').astype('float')
    #Дадим имена столбцам датасетов
    vars()['table_'+ str(i)].columns = ['Регион',
                                        'Радикальное лечение закончено, абс.',
                                        'Радикальное лечение закончено, %',
                                        'Лечение будет продолжено, абс.',
                                        'Лечение будет продолжено, %',
                                        'Хирургический метод, %',
                                        'Лучевой метод, %',
                                        'Лекарственный метод, %',
                                        'Комбинированный метод (кроме химио-лучевого), %',
                                        'Химио-лучевой метод, %']
    #Применим к датасетам функцию `fo_column_creation` для добавления столбца с федеральными округами
    vars()['table_'+ str(i)] = fo_column_creation(vars()['table_'+ str(i)])
    #Добавим столбец с локализацией опухоли. Для этого разобьём очередное значение из списка localization по разделителю '(C', учтя при этом русскую и английскую раскладку
    #В таблицы 59 и 60 добавим столбец не с локализацией, а с возрастной группой
    if i == 59 or i == 60:
        vars()['table_'+ str(i)].insert(0,'Возрастная группа', re.split('\(C|\(С', localization[j-2])[0].strip())
    else:
        vars()['table_'+ str(i)].insert(0,'Локализация опухоли', re.split('\(C|\(С', localization[j-2])[0].strip())
    #Добавим столбец с кодом по МКБ-10. Для этого возьмём код из второй части разбитого сначения из списка localization, выбросив закрывающую скобку, и добавим к коду 'C'
    vars()['table_'+ str(i)].insert(1,'Код МКБ-10', 'C' + re.search(r'[^)]+', re.split('\(C|\(С', localization[j-2])[1]).group(0))
    #Применим к датасетам функцию `c_mkb` для замены всех С на латиницу
    vars()['table_'+ str(i)] = c_mkb(vars()['table_'+ str(i)])
    #Запишем имя таблицы в список tables
    tables.append(vars()['table_'+ str(i)])
    #Увеличим счётчик url-адреса
    j += 1

# %% [markdown]
# Проверим корректность на нескольких таблицах

# %%
table_58.head()
# Out:
#                        Локализация опухоли Код МКБ-10 Федеральный округ  \
# 1  Злокачественные новообразования - всего     C00-96    Центральный ФО
# 2  Злокачественные новообразования - всего     C00-96    Центральный ФО
# 3  Злокачественные новообразования - всего     C00-96    Центральный ФО
# 4  Злокачественные новообразования - всего     C00-96    Центральный ФО
# 5  Злокачественные новообразования - всего     C00-96    Центральный ФО
#
#                  Регион  Радикальное лечение закончено, абс.  \
# 1  Белгородская область                                 3952
# 2      Брянская область                                 2673
# 3  Владимирская область                                 2858
# 4   Воронежская область                                 5305
# 5    Ивановская область                                 2289
#
#    Радикальное лечение закончено, %  Лечение будет продолжено, абс.  \
# 1                              57.1                            1418
# 2                              46.9                            1236
# 3                              51.9                             808
# 4                              58.8                            1635
# 5                              49.9                             553
#
#    Лечение будет продолжено, %  Хирургический метод, %  Лучевой метод, %  \
# 1                         20.5                    53.6              12.7
# 2                         21.7                    54.0               2.3
# 3                         14.7                    59.0               2.4
# 4                         18.1                    53.9               9.4
# 5                         12.1                    58.0              10.6
#
#    Лекарственный метод, %  Комбинированный метод (кроме химио-лучевого), %  \
# 1                     2.9                                             27.9
# 2                     7.6                                             34.3
# 3                     0.0                                             37.5
# 4                     2.3                                             32.5
# 5                     1.8                                             28.0
#
#    Химио-лучевой метод, %
# 1                     2.9
# 2                     1.8
# 3                     1.1
# 4                     1.8
# 5                     1.7

# %%
table_65.tail()
# Out:
#    Локализация опухоли Код МКБ-10   Федеральный округ  \
# 88             Желудок        C16  Дальневосточный ФО
# 89             Желудок        C16  Дальневосточный ФО
# 90             Желудок        C16  Дальневосточный ФО
# 91             Желудок        C16  Дальневосточный ФО
# 92             Желудок        C16  Дальневосточный ФО
#
#                       Регион  Радикальное лечение закончено, абс.  \
# 88        Забайкальский край                                   36
# 89       Чукотский авт.округ                                    3
# 90        Республика Бурятия                                  104
# 91  Республика Саха (Якутия)                                   49
# 92       Еврейская авт. обл.                                    3
#
#     Радикальное лечение закончено, %  Лечение будет продолжено, абс.  \
# 88                              18.8                              46
# 89                              23.1                               1
# 90                              40.6                              35
# 91                              30.4                              14
# 92                              13.0                               3
#
#     Лечение будет продолжено, %  Хирургический метод, %  Лучевой метод, %  \
# 88                         24.0                    61.1               0.0
# 89                          7.7                    66.7               0.0
# 90                         13.7                    57.7               0.0
# 91                          8.7                    55.1               0.0
# 92                         13.0                   100.0               0.0
#
#     Лекарственный метод, %  Комбинированный метод (кроме химио-лучевого), %  \
# 88                     0.0                                             38.9
# 89                     0.0                                             33.3
# 90                     0.0                                             42.3
# 91                     0.0                                             44.9
# 92                     0.0                                              0.0
#
#     Химио-лучевой метод, %
# 88                     0.0
# 89                     0.0
# 90                     0.0
# 91                     0.0
# 92                     0.0

# %%
table_59.head()
# Out:
#              Возрастная группа Код МКБ-10 Федеральный округ  \
# 1  У детей в возрасте 0-14 лет     C00-96    Центральный ФО
# 2  У детей в возрасте 0-14 лет     C00-96    Центральный ФО
# 3  У детей в возрасте 0-14 лет     C00-96    Центральный ФО
# 4  У детей в возрасте 0-14 лет     C00-96    Центральный ФО
# 5  У детей в возрасте 0-14 лет     C00-96    Центральный ФО
#
#                  Регион  Радикальное лечение закончено, абс.  \
# 1  Белгородская область                                    3
# 2      Брянская область                                   23
# 3  Владимирская область                                    2
# 4   Воронежская область                                    5
# 5    Ивановская область                                    9
#
#    Радикальное лечение закончено, %  Лечение будет продолжено, абс.  \
# 1                              11.1                              22
# 2                              63.9                               9
# 3                              14.3                              12
# 4                              33.3                              10
# 5                              42.9                               2
#
#    Лечение будет продолжено, %  Хирургический метод, %  Лучевой метод, %  \
# 1                         81.5                    66.7               0.0
# 2                         25.0                    21.7               0.0
# 3                         85.7                    50.0               0.0
# 4                         66.7                     0.0               0.0
# 5                          9.5                    22.2               0.0
#
#    Лекарственный метод, %  Комбинированный метод (кроме химио-лучевого), %  \
# 1                    33.3                                              0.0
# 2                    60.9                                              8.7
# 3                     0.0                                             50.0
# 4                    80.0                                             20.0
# 5                    55.6                                             22.2
#
#    Химио-лучевой метод, %
# 1                     0.0
# 2                     8.7
# 3                     0.0
# 4                     0.0
# 5                     0.0

# %%
table_60.tail()
# Out:
#               Возрастная группа Код МКБ-10   Федеральный округ  \
# 86  У детей в возрасте 0-17 лет     C00-96  Дальневосточный ФО
# 87  У детей в возрасте 0-17 лет     C00-96  Дальневосточный ФО
# 88  У детей в возрасте 0-17 лет     C00-96  Дальневосточный ФО
# 89  У детей в возрасте 0-17 лет     C00-96  Дальневосточный ФО
# 90  У детей в возрасте 0-17 лет     C00-96  Дальневосточный ФО
#
#                       Регион  Радикальное лечение закончено, абс.  \
# 86        Забайкальский край                                   12
# 87       Чукотский авт.округ                                    0
# 88        Республика Бурятия                                   17
# 89  Республика Саха (Якутия)                                   17
# 90       Еврейская авт. обл.                                    0
#
#     Радикальное лечение закончено, %  Лечение будет продолжено, абс.  \
# 86                              41.4                              13
# 87                               0.0                               1
# 88                              58.6                              11
# 89                              56.7                              13
# 90                               0.0                               3
#
#     Лечение будет продолжено, %  Хирургический метод, %  Лучевой метод, %  \
# 86                         44.8                    33.3               0.0
# 87                        100.0                     0.0               0.0
# 88                         37.9                    11.8               0.0
# 89                         43.3                    35.3               0.0
# 90                         60.0                     0.0               0.0
#
#     Лекарственный метод, %  Комбинированный метод (кроме химио-лучевого), %  \
# 86                    33.3                                             16.7
# 87                     0.0                                              0.0
# 88                    70.6                                             17.6
# 89                    52.9                                             11.8
# 90                     0.0                                              0.0
#
#     Химио-лучевой метод, %
# 86                    16.7
# 87                     0.0
# 88                     0.0
# 89                     0.0
# 90                     0.0

# %% [markdown]
# Объединим таблицы 59 и 60 в одну. Это данные о лечении детей

# %%
table_59_60 = pd.concat(tables[1:3])

# %%
table_59_60
# Out:
#               Возрастная группа Код МКБ-10   Федеральный округ  \
# 1   У детей в возрасте 0-14 лет     C00-96      Центральный ФО
# 2   У детей в возрасте 0-14 лет     C00-96      Центральный ФО
# 3   У детей в возрасте 0-14 лет     C00-96      Центральный ФО
# 4   У детей в возрасте 0-14 лет     C00-96      Центральный ФО
# 5   У детей в возрасте 0-14 лет     C00-96      Центральный ФО
# ..                          ...        ...                 ...
# 86  У детей в возрасте 0-17 лет     C00-96  Дальневосточный ФО
# 87  У детей в возрасте 0-17 лет     C00-96  Дальневосточный ФО
# 88  У детей в возрасте 0-17 лет     C00-96  Дальневосточный ФО
# 89  У детей в возрасте 0-17 лет     C00-96  Дальневосточный ФО
# 90  У детей в возрасте 0-17 лет     C00-96  Дальневосточный ФО
#
#                       Регион  Радикальное лечение закончено, абс.  \
# 1       Белгородская область                                    3
# 2           Брянская область                                   23
# 3       Владимирская область                                    2
# 4        Воронежская область                                    5
# 5         Ивановская область                                    9
# ..                       ...                                  ...
# 86        Забайкальский край                                   12
# 87       Чукотский авт.округ                                    0
# 88        Республика Бурятия                                   17
# 89  Республика Саха (Якутия)                                   17
# 90       Еврейская авт. обл.                                    0
#
#     Радикальное лечение закончено, %  Лечение будет продолжено, абс.  \
# 1                               11.1                              22
# 2                               63.9                               9
# 3                               14.3                              12
# 4                               33.3                              10
# 5                               42.9                               2
# ..                               ...                             ...
# 86                              41.4                              13
# 87                               0.0                               1
# 88                              58.6                              11
# 89                              56.7                              13
# 90                               0.0                               3
#
#     Лечение будет продолжено, %  Хирургический метод, %  Лучевой метод, %  \
# 1                          81.5                    66.7               0.0
# 2                          25.0                    21.7               0.0
# 3                          85.7                    50.0               0.0
# 4                          66.7                     0.0               0.0
# 5                           9.5                    22.2               0.0
# ..                          ...                     ...               ...
# 86                         44.8                    33.3               0.0
# 87                        100.0                     0.0               0.0
# 88                         37.9                    11.8               0.0
# 89                         43.3                    35.3               0.0
# 90                         60.0                     0.0               0.0
#
#     Лекарственный метод, %  Комбинированный метод (кроме химио-лучевого), %  \
# 1                     33.3                                              0.0
# 2                     60.9                                              8.7
# 3                      0.0                                             50.0
# 4                     80.0                                             20.0
# 5                     55.6                                             22.2
# ..                     ...                                              ...
# 86                    33.3                                             16.7
# 87                     0.0                                              0.0
# 88                    70.6                                             17.6
# 89                    52.9                                             11.8
# 90                     0.0                                              0.0
#
#     Химио-лучевой метод, %
# 1                      0.0
# 2                      8.7
# 3                      0.0
# 4                      0.0
# 5                      0.0
# ..                     ...
# 86                    16.7
# 87                     0.0
# 88                     0.0
# 89                     0.0
# 90                     0.0
#
# [166 rows x 13 columns]

# %% [markdown]
# Объединим таблицы с 61 по 85 в одну. Это данные о лечении разных локализаций опухолей

# %%
table_61_85 = pd.concat(tables[3:])

# %%
table_61_85.head(10)
# Out:
#    Локализация опухоли Код МКБ-10 Федеральный округ                Регион  \
# 1                 Губа        C00    Центральный ФО  Белгородская область
# 2                 Губа        C00    Центральный ФО      Брянская область
# 3                 Губа        C00    Центральный ФО  Владимирская область
# 4                 Губа        C00    Центральный ФО   Воронежская область
# 5                 Губа        C00    Центральный ФО    Ивановская область
# 6                 Губа        C00    Центральный ФО      Тверская область
# 7                 Губа        C00    Центральный ФО     Калужская область
# 8                 Губа        C00    Центральный ФО   Костромская область
# 9                 Губа        C00    Центральный ФО       Курская область
# 10                Губа        C00    Центральный ФО      Липецкая область
#
#     Радикальное лечение закончено, абс.  Радикальное лечение закончено, %  \
# 1                                    20                              87.0
# 2                                     6                              30.0
# 3                                    16                              88.9
# 4                                    40                              85.1
# 5                                    15                              75.0
# 6                                    17                              89.5
# 7                                     6                              75.0
# 8                                     6                              50.0
# 9                                    32                              97.0
# 10                                   10                              71.4
#
#     Лечение будет продолжено, абс.  Лечение будет продолжено, %  \
# 1                                1                          4.3
# 2                               13                         65.0
# 3                                0                          0.0
# 4                                5                         10.6
# 5                                2                         10.0
# 6                                1                          5.3
# 7                                0                          0.0
# 8                                0                          0.0
# 9                                0                          0.0
# 10                               3                         21.4
#
#     Хирургический метод, %  Лучевой метод, %  Лекарственный метод, %  \
# 1                     60.0              35.0                     0.0
# 2                     16.7              50.0                     0.0
# 3                     87.5               0.0                     0.0
# 4                     50.0              27.5                     0.0
# 5                     66.7              20.0                     0.0
# 6                     70.6              11.8                     0.0
# 7                     66.7              33.3                     0.0
# 8                    100.0               0.0                     0.0
# 9                     53.1              31.3                     0.0
# 10                    60.0              20.0                     0.0
#
#     Комбинированный метод (кроме химио-лучевого), %  Химио-лучевой метод, %
# 1                                               5.0                     0.0
# 2                                              33.3                     0.0
# 3                                              12.5                     0.0
# 4                                              22.5                     0.0
# 5                                              13.3                     0.0
# 6                                              11.8                     5.9
# 7                                               0.0                     0.0
# 8                                               0.0                     0.0
# 9                                              15.6                     0.0
# 10                                             10.0                    10.0

# %% [markdown]
# Добавим в таблицу новые столбцы - с группами опухолей по их локализации и  диапазонами кодов МКБ-10 для каждой группы. Это нужно для того, чтобы медики могли выбирать для демонстрации на дашборде либо названия ЗНО, либо их коды МКБ-10.

# %% [markdown]
# Создадим словарь, ключами в котором будут кортежи, содержащие название группы опухолей и диапазон кодов МКБ-10 в зависимости от локализации опухоли, а значениями - списки кодов МКБ-10 конкретных опухолей.

# %%
codes = {('Губы, полости рта и глотки', 'С00-С13'): ['C00', 'C01-09', 'C10-13'],
         ('Органов пищеварения', 'С15-С25'): ['C15', 'C16', 'C17', 'C18', 'C19-21', 'C22', 'C25'],
         ('Органов дыхания и грудной клетки', 'С32-34'): ['C32', 'C33,34'],
         ('Костей и суставных хрящей', 'С40-С41'): 'C40,41',
         ('Кожи', 'С43-44'): ['C43', 'C44'],
         ('Мезотелиальной и мягких тканей', 'С47-С49'): ['C47,49'],
         ('Молочной железы', 'С50'): ['С50'],
         ('Женских половых органов', 'С53-С56'): ['C53', 'C54', 'C56'],
         ('Мужских половых органов', 'С61'): ['С61'],
         ('Мочевых путей', 'С64-С67'): ['C64', 'C67'],
         ('Щитовидной железы', 'С73'): ['С73'],
         ('Лимфоидной и кроветворной тканей', 'С81-С95'): ['C81-86;88,90,96', 'C91-95']}

# %% [markdown]
# Объявим функцию, которая будет принимать на вход содержимое ячейки и условный номер столбца (1 - столбец с названиями опухолей, 2 - столбец с кодами МКБ-10) и искать содержимое ячейки в значениях словаря для каждого ключа. Возвращает функция первое или второе значения кортежа из ключей словаря.

# %%
def make_code(cell, col):
    for key, value in codes.items():
        if cell in value and col == 1:
            return key[0]
        elif cell in value and col == 2:
            return key[1]

# %% [markdown]
# Объявим функцию, которая будет добавлять в таблицу новые столбцы с группами опухолей по их локализации и диапазонами кодов МКБ-10.

# %%
def group_of_tumors(table):
    table.insert(0,'Группа опухолей', '')
    table['Группа опухолей'] = table['Код МКБ-10'].apply(lambda x: make_code(x, 1))

    table.insert(2,'Группа кодов МКБ-10', '')
    table['Группа кодов МКБ-10'] = table['Код МКБ-10'].apply(lambda x: make_code(x, 2))

    return(table)

# %% [markdown]
# Добавим в датасет `table_61_85` столбцы, куда занесём группы опухолей по их локализации и группы по МКБ-10.

# %%
table_61_85 = group_of_tumors(table_61_85)

# %%
table_61_85.head()
# Out:
#               Группа опухолей Локализация опухоли Группа кодов МКБ-10  \
# 1  Губы, полости рта и глотки                Губа             С00-С13
# 2  Губы, полости рта и глотки                Губа             С00-С13
# 3  Губы, полости рта и глотки                Губа             С00-С13
# 4  Губы, полости рта и глотки                Губа             С00-С13
# 5  Губы, полости рта и глотки                Губа             С00-С13
#
#   Код МКБ-10 Федеральный округ                Регион  \
# 1        C00    Центральный ФО  Белгородская область
# 2        C00    Центральный ФО      Брянская область
# 3        C00    Центральный ФО  Владимирская область
# 4        C00    Центральный ФО   Воронежская область
# 5        C00    Центральный ФО    Ивановская область
#
#    Радикальное лечение закончено, абс.  Радикальное лечение закончено, %  \
# 1                                   20                              87.0
# 2                                    6                              30.0
# 3                                   16                              88.9
# 4                                   40                              85.1
# 5                                   15                              75.0
#
#    Лечение будет продолжено, абс.  Лечение будет продолжено, %  \
# 1                               1                          4.3
# 2                              13                         65.0
# 3                               0                          0.0
# 4                               5                         10.6
# 5                               2                         10.0
#
#    Хирургический метод, %  Лучевой метод, %  Лекарственный метод, %  \
# 1                    60.0              35.0                     0.0
# 2                    16.7              50.0                     0.0
# 3                    87.5               0.0                     0.0
# 4                    50.0              27.5                     0.0
# 5                    66.7              20.0                     0.0
#
#    Комбинированный метод (кроме химио-лучевого), %  Химио-лучевой метод, %
# 1                                              5.0                     0.0
# 2                                             33.3                     0.0
# 3                                             12.5                     0.0
# 4                                             22.5                     0.0
# 5                                             13.3                     0.0

# %% [markdown]
# Записываем полученные файлы на диск

# %%
drive.mount('drive')

#table_54.to_csv('/content/drive/My Drive/oncology_project_tables/table_54.csv', encoding='utf-8', index=False)
#rus_methods.to_csv('/content/drive/My Drive/oncology_project_tables/rus_methods.csv', encoding='utf-8', index=False)
#table_57.to_csv('/content/drive/My Drive/oncology_project_tables/table_57.csv', encoding='utf-8', index=False)
#table_58.to_csv('/content/drive/My Drive/oncology_project_tables/table_58.csv', encoding='utf-8', index=False)
#table_59_60.to_csv('/content/drive/My Drive/oncology_project_tables/table_59_60.csv', encoding='utf-8', index=False)
#table_61_85.to_csv('/content/drive/My Drive/oncology_project_tables/table_61_85.csv', encoding='utf-8', index=False)
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).
